# %% [markdown]
# ## Pandas-DataFrame And Series
# Pandas is a powerful data manipulation library in python, widely used for data analysis and data cleaning. It provides two primary data structures: Series and DataFrame . A Series is a one-dimensional array-like object, while a DataFrame is a two-dimensional, size-mutable, and potentially hetrogeneous tabular data Structure while labeled axes (rows and columns).

# %%
import pandas as pd

# %%
## Series 
## Pandas Series a one-dimensional array-like object that can hold any data type 

data=[1,3,4,5]
series=pd.Series(data)
print("Series\n",series)
print(type(series))
# Out:
# Series
#  0    1
# 1    3
# 2    4
# 3    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
## Create a series from dictionary 
data={'a':1,'b':2,'c':3}
series=pd.Series(data)
print(series)
print(type(series))
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
data=[10,20,30]
index=['a','b','c']

series=pd.Series(data,index=index)
print(series)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
## DataFrame 
## Create a dataframe from a dictionary of list

data={
    'name':['madhav','subodh','suraj','vishal'],
    'age':[23,24,56,75],
    'city':['delshi','patna','mumbai','goa']
}
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#      name  age    city
# 0  madhav   23  delshi
# 1  subodh   24   patna
# 2   suraj   56  mumbai
# 3  vishal   75     goa
# <class 'pandas.core.frame.DataFrame'>

# %%
import numpy as np

# %%
## Create a Data frame From a list of dictionary

data=[
   {'name':'madhav','age':32,'city':'jaipur'},
    {'name':'subodh','age':43,'city':'mumbai'}
]

df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#      name  age    city
# 0  madhav   32  jaipur
# 1  subodh   43  mumbai
# <class 'pandas.core.frame.DataFrame'>

# %%
data
# Out:
# [{'name': 'madhav', 'age': 32, 'city': 'jaipur'},
#  {'name': 'subodh', 'age': 43, 'city': 'mumbai'}]

# %%
data
# Out:
# [{'name': 'madhav', 'age': 32, 'city': 'jaipur'},
#  {'name': 'subodh', 'age': 43, 'city': 'mumbai'}]

# %%
df
# Out:
#      name  age    city
# 0  madhav   32  jaipur
# 1  subodh   43  mumbai

# %%
df['name']
# Out:
# 0    madhav
# 1    subodh
# Name: name, dtype: object

# %%
df.loc[0]
# Out:
# name    madhav
# age         32
# city    jaipur
# Name: 0, dtype: object

# %%
df.loc[0][0]
# Out:
# C:\Users\Madhav Yadav\AppData\Local\Temp\ipykernel_12332\2527876973.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[0][0]
# 'madhav'

# %%
## Accessing a specified element 
df.at[0,'age']
# Out:
# np.int64(32)

# %%
## Accessing a specified element using iat
df.iat[2,2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12332\1958317854.py in ?()
#       1 ## Accessing a specified element using iat
# ----> 2 df.iat[2,2]
#
# ~\myenv\Lib\site-packages\pandas\core\indexing.py in ?(self, key)
#    2523             else:
#    2524                 raise ValueError("Invalid call for scalar access (getting)!")
#    2525
#    2526         key = self._convert_key(key)
# -> 2527         return self.obj._get_value(*key, takeable=self._takeable)
#
# ~\myenv\Lib\site-packages\pandas\core\frame.py in ?(self, index, col, takeable)
#    4213         `self.columns._index_as_unique`; Caller is responsible for checking.
#    4214         """
#    4215         if takeable:
#    4216             series = self._ixs(col, axis=1)
# -> 4217             return series._values[index]
#    4218
#    4219         series = self._get_item_cache(col)
#    4220         engine = self.index._engine
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
df
# Out:
#      name  age    city
# 0  madhav   32  jaipur
# 1  subodh   43  mumbai

# %%
## Data Manipulation with Dataframe
df
# Out:
#      name  age    city
# 0  madhav   32  jaipur
# 1  subodh   43  mumbai

# %%
df['salary']=[80000,90000]
df
# Out:
#      name  age    city  salary
# 0  madhav   32  jaipur   80000
# 1  subodh   43  mumbai   90000

# %%
## Delete the columns 

df.drop('salary',axis=1) # Not delete the parmenent
# Out:
#      name  age    city
# 0  madhav   32  jaipur
# 1  subodh   43  mumbai

# %%
df
# Out:
#      name  age    city  salary
# 0  madhav   32  jaipur   80000
# 1  subodh   43  mumbai   90000

# %%
# delete the parmenent 
df.drop(['salary'],axis=1,inplace=True)

# %%
df
# Out:
#      name  age    city
# 0  madhav   32  jaipur
# 1  subodh   43  mumbai

# %%
df['age']=df['age'] +3
df
# Out:
#      name  age    city
# 0  madhav   35  jaipur
# 1  subodh   46  mumbai

# %%
df.drop(0,inplace = True)

# %%
df
# Out:
#      name  age    city
# 1  subodh   46  mumbai

# %%
df.describe()
# Out:
#         age
# count   1.0
# mean   46.0
# std     NaN
# min    46.0
# 25%    46.0
# 50%    46.0
# 75%    46.0
# max    46.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 1 to 1
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    1 non-null      object
#  1   age     1 non-null      int64
#  2   city    1 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 156.0+ bytes

# %% [markdown]
# ## Data Manipulation and Analysis with Pandas
#
# Data manipulation and analysis are key tasks in any data science or dat analysis project. Pandas provides a wide range of functions for data manipulation and analysis, making it easier to clean, transform and extract insights from data. in this lesson, well will cover various data manipulation and analysis techniques using Pandas.

# %%
data=pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
data.tail()
# Out:
#       ID     crim   zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 328  500  0.17783  0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 328     19.2  395.77  15.10  17.5
# 329     21.0  391.99   9.67  22.4
# 330     21.0  396.90   9.08  20.6
# 331     21.0  396.90   5.64  23.9
# 332     21.0  396.90   7.88  11.9

# %%
data.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean   250.951952    3.360341   10.689189   11.293483    0.060060    0.557144
# std    147.859438    7.352272   22.674762    6.998123    0.237956    0.114955
# min      1.000000    0.006320    0.000000    0.740000    0.000000    0.385000
# 25%    123.000000    0.078960    0.000000    5.130000    0.000000    0.453000
# 50%    244.000000    0.261690    0.000000    9.900000    0.000000    0.538000
# 75%    377.000000    3.678220   12.500000   18.100000    0.000000    0.631000
# max    506.000000   73.534100  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     6.265619   68.226426    3.709934    9.633634  409.279279   18.448048
# std      0.703952   28.133344    1.981123    8.742174  170.841988    2.151821
# min      3.561000    6.000000    1.129600    1.000000  188.000000   12.600000
# 25%      5.884000   45.400000    2.122400    4.000000  279.000000   17.400000
# 50%      6.202000   76.700000    3.092300    5.000000  330.000000   19.000000
# 75%      6.595000   93.800000    5.116700   24.000000  666.000000   20.200000
# max      8.725000  100.000000   10.710300   24.000000  711.000000   21.200000
#
#             black       lstat        medv
# count  333.000000  333.000000  333.000000
# mean   359.466096   12.515435   22.768769
# std     86.584567    7.067781    9.173468
# min      3.500000    1.730000    5.000000
# 25%    376.730000    7.180000   17.400000
# 50%    392.050000   10.970000   21.600000
# 75%    396.240000   16.420000   25.000000
# max    396.900000   37.970000   50.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       333 non-null    int64
#  1   crim     333 non-null    float64
#  2   zn       333 non-null    float64
#  3   indus    333 non-null    float64
#  4   chas     333 non-null    int64
#  5   nox      333 non-null    float64
#  6   rm       333 non-null    float64
#  7   age      333 non-null    float64
#  8   dis      333 non-null    float64
#  9   rad      333 non-null    int64
#  10  tax      333 non-null    int64
#  11  ptratio  333 non-null    float64
#  12  black    333 non-null    float64
#  13  lstat    333 non-null    float64
#  14  medv     333 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 39.2 KB

# %%
data.dtypes
# Out:
# ID           int64
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# black      float64
# lstat      float64
# medv       float64
# dtype: object

# %%
## Handling Missing Value
data.isnull().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 328    False
# 329    False
# 330    False
# 331    False
# 332    False
# Length: 333, dtype: bool

# %%
data.isnull().any()
# Out:
# ID         False
# crim       False
# zn         False
# indus      False
# chas       False
# nox        False
# rm         False
# age        False
# dis        False
# rad        False
# tax        False
# ptratio    False
# black      False
# lstat      False
# medv       False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# ID         0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
data.fillna(0)
# Out:
#       ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4      7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  500  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       18.7  394.63   2.94  33.4
# 3       18.7  396.90   5.33  36.2
# 4       15.2  395.60  12.43  22.9
# ..       ...     ...    ...   ...
# 328     19.2  395.77  15.10  17.5
# 329     21.0  391.99   9.67  22.4
# 330     21.0  396.90   9.08  20.6
# 331     21.0  396.90   5.64  23.9
# 332     21.0  396.90   7.88  11.9
#
# [333 rows x 15 columns]

# %%
## Filling missing value with the mean of the column

data['crim']=data['crim'].fillna(data['crim'].mean())

# %%
data.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
df.dtypes
# Out:
# name    object
# age      int64
# city    object
# dtype: object

# %%
## Renaming Columns

data=data.rename(columns={'crim':'crime'})
data
# Out:
#       ID    crime    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4      7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  500  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       18.7  394.63   2.94  33.4
# 3       18.7  396.90   5.33  36.2
# 4       15.2  395.60  12.43  22.9
# ..       ...     ...    ...   ...
# 328     19.2  395.77  15.10  17.5
# 329     21.0  391.99   9.67  22.4
# 330     21.0  396.90   9.08  20.6
# 331     21.0  396.90   5.64  23.9
# 332     21.0  396.90   7.88  11.9
#
# [333 rows x 15 columns]

# %%
## Change datatypes 

data['age']=data['age'].astype(int)
data.head()
# Out:
#    ID    crime    zn  indus  chas    nox     rm  age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575   65  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421   78  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998   45  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147   54  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012   66  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
data.dtypes
# Out:
# ID           int64
# crime      float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age          int64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# black      float64
# lstat      float64
# medv       float64
# dtype: object

# %%
data['new_age']=data['age'].apply(lambda x:x*2)

# %%
data.head()
# Out:
#    ID    crime    zn  indus  chas    nox     rm  age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575   65  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421   78  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998   45  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147   54  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012   66  5.5605    5  311
#
#    ptratio   black  lstat  medv  new_age
# 0     15.3  396.90   4.98  24.0      130
# 1     17.8  396.90   9.14  21.6      156
# 2     18.7  394.63   2.94  33.4       90
# 3     18.7  396.90   5.33  36.2      108
# 4     15.2  395.60  12.43  22.9      132

# %%
# ## Data Aggreating and Grouping 
# grouped_mean=data.groupby('chas')['rm'].mean()
# print(grouped_mean)

# %%
## Merging and joining DataFrame
# Create smaples 

df1=pd.DataFrame({'key':['A','B','C'],'Value1':[1,2,3]})
df2=pd.DataFrame({'key':['A','B','D'],'Value2':[4,5,6]})

# %%
df1
# Out:
#   key  Value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2
# Out:
#   key  Value2
# 0   A       4
# 1   B       5
# 2   D       6

# %%
## Merge DataFrame on the 'Key' columns 
pd.merge(df1,df2,on="key",how='inner')
# Out:
#   key  Value1  Value2
# 0   A       1       4
# 1   B       2       5

# %%
pd.merge(df1,df2,on="key",how='outer')
# Out:
#   key  Value1  Value2
# 0   A     1.0     4.0
# 1   B     2.0     5.0
# 2   C     3.0     NaN
# 3   D     NaN     6.0

# %%
pd.merge(df1,df2,on="key",how='left')
# Out:
#   key  Value1  Value2
# 0   A       1     4.0
# 1   B       2     5.0
# 2   C       3     NaN

# %%
pd.merge(df1,df2,on="key",how='right')
# Out:
#   key  Value1  Value2
# 0   A     1.0       4
# 1   B     2.0       5
# 2   D     NaN       6

# %% [markdown]
# ## Reading Data From Different Sources

# %%
data='{"employee_name":"Madhav","email":"ymadhav@gamil.com","job_profile": [{"title1":"Team Lead","title2":"Sr. Developer"}'

# %%
from io import StringIO

# %%
data
# Out:
# '{"employee_name":"Madhav","email":"ymadhav@gamil.com","job_profile": [{"title1":"Team Lead","title2":"Sr. Developer"}'

# %%
import pandas as pd
import json

# %%
# !pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-6.0.2-cp313-cp313-win_amd64.whl.metadata (3.7 kB)
# Downloading lxml-6.0.2-cp313-cp313-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 402.7 kB/s eta 0:00:09
#    ----- ---------------------------------- 0.5/4.0 MB 402.7 kB/s eta 0:00:09
#    ----- ---------------------------------- 0.5/4.0 MB 402.7 kB/s eta 0:00:09
#    ------- -------------------------------- 0.8/4.0 MB 412.6 kB/s eta 0:00:08
#    ------- -------------------------------- 0.8/4.0 MB 412.6 kB/s eta 0:00:08
#    ------- -------------------------------- 0.8/4.0 MB 412.6 kB/s eta 0:00:08
#    ---------- ----------------------------- 1.0/4.0 MB 426.8 kB/s eta 0:00:07
#    ---------- ----------------------------- 1.0/4.0 MB 426.8 kB/s eta 0:00:07
#    ------------- -------------------------- 1.3/4.0 MB 437.7 kB/s eta 0:00:07
#    ------------- -------------------------- 1.3/4.0 MB 437.7 kB/s eta 0:00:07
#    ------------- -------------------------- 1.3/4.0 MB 437.7 kB/s eta 0:00:07
#    ------------- -------------------------- 1.3/4.0 MB 437.7 kB/s eta 0:00:07
#    ------------- -------------------------- 1.3/4.0 MB 437.7 kB/s eta 0:00:07
#    ------------- -------------------------- 1.3/4.0 MB 437.7 kB/s eta 0:00:07
#    ------------- -------------------------- 1.3/4.0 MB 437.7 kB/s eta 0:00:07
#    --------------- ------------------------ 1.6/4.0 MB 346.8 kB/s eta 0:00:08
#    --------------- ------------------------ 1.6/4.0 MB 346.8 kB/s eta 0:00:08
#    --------------- ------------------------ 1.6/4.0 MB 346.8 kB/s eta 0:00:08
#    --------------- ------------------------ 1.6/4.0 MB 346.8 kB/s eta 0:00:08
#    --------------- ------------------------ 1.6/4.0 MB 346.8 kB/s eta 0:00:08
#    ------------------ --------------------- 1.8/4.0 MB 310.9 kB/s eta 0:00:07
#    ------------------ --------------------- 1.8/4.0 MB 310.9 kB/s eta 0:00:07
#    ------------------ --------------------- 1.8/4.0 MB 310.9 kB/s eta 0:00:07
#    ------------------ --------------------- 1.8/4.0 MB 310.9 kB/s eta 0:00:07
#    ------------------ --------------------- 1.8/4.0 MB 310.9 kB/s eta 0:00:07
#    ------------------ --------------------- 1.8/4.0 MB 310.9 kB/s eta 0:00:07
#    ------------------ --------------------- 1.8/4.0 MB 310.9 kB/s eta 0:00:07
#    ------------------ --------------------- 1.8/4.0 MB 310.9 kB/s eta 0:00:07
#    ------------------ --------------------- 1.8/4.0 MB 310.9 kB/s eta 0:00:07
#    ------------------ --------------------- 1.8/4.0 MB 310.9 kB/s eta 0:00:07
#    -------------------- ------------------- 2.1/4.0 MB 255.7 kB/s eta 0:00:08
#    -------------------- ------------------- 2.1/4.0 MB 255.7 kB/s eta 0:00:08
#    -------------------- ------------------- 2.1/4.0 MB 255.7 kB/s eta 0:00:08
#    -------------------- ------------------- 2.1/4.0 MB 255.7 kB/s eta 0:00:08
#    -------------------- ------------------- 2.1/4.0 MB 255.7 kB/s eta 0:00:08
#    -------------------- ------------------- 2.1/4.0 MB 255.7 kB/s eta 0:00:08
#    -------------------- ------------------- 2.1/4.0 MB 255.7 kB/s eta 0:00:08
#    -------------------- ------------------- 2.1/4.0 MB 255.7 kB/s eta 0:00:08
#    -------------------- ------------------- 2.1/4.0 MB 255.7 kB/s eta 0:00:08
#    -------------------- ------------------- 2.1/4.0 MB 255.7 kB/s eta 0:00:08
#    -------------------- ------------------- 2.1/4.0 MB 255.7 kB/s eta 0:00:08
#    ----------------------- ---------------- 2.4/4.0 MB 218.0 kB/s eta 0:00:08
#    ----------------------- ---------------- 2.4/4.0 MB 218.0 kB/s eta 0:00:08
#    ----------------------- ---------------- 2.4/4.0 MB 218.0 kB/s eta 0:00:08
#    ----------------------- ---------------- 2.4/4.0 MB 218.0 kB/s eta 0:00:08
#    ----------------------- ---------------- 2.4/4.0 MB 218.0 kB/s eta 0:00:08
#    ----------------------- ---------------- 2.4/4.0 MB 218.0 kB/s eta 0:00:08
#    ----------------------- ---------------- 2.4/4.0 MB 218.0 kB/s eta 0:00:08
#    ----------------------- ---------------- 2.4/4.0 MB 218.0 kB/s eta 0:00:08
#    ----------------------- ---------------- 2.4/4.0 MB 218.0 kB/s eta 0:00:08
#    ----------------------- ---------------- 2.4/4.0 MB 218.0 kB/s eta 0:00:08
#    ----------------------- ---------------- 2.4/4.0 MB 218.0 kB/s eta 0:00:08
#    -------------------------- ------------- 2.6/4.0 MB 196.2 kB/s eta 0:00:08
#    -------------------------- ------------- 2.6/4.0 MB 196.2 kB/s eta 0:00:08
#    -------------------------- ------------- 2.6/4.0 MB 196.2 kB/s eta 0:00:08
#    -------------------------- ------------- 2.6/4.0 MB 196.2 kB/s eta 0:00:08
#    -------------------------- ------------- 2.6/4.0 MB 196.2 kB/s eta 0:00:08
#    -------------------------- ------------- 2.6/4.0 MB 196.2 kB/s eta 0:00:08
#    ---------------------------- ----------- 2.9/4.0 MB 199.3 kB/s eta 0:00:06
#    ---------------------------- ----------- 2.9/4.0 MB 199.3 kB/s eta 0:00:06
#    ---------------------------- ----------- 2.9/4.0 MB 199.3 kB/s eta 0:00:06
#    ---------------------------- ----------- 2.9/4.0 MB 199.3 kB/s eta 0:00:06
#    ---------------------------- ----------- 2.9/4.0 MB 199.3 kB/s eta 0:00:06
#    ---------------------------- ----------- 2.9/4.0 MB 199.3 kB/s eta 0:00:06
#    ---------------------------- ----------- 2.9/4.0 MB 199.3 kB/s eta 0:00:06
#    ---------------------------- ----------- 2.9/4.0 MB 199.3 kB/s eta 0:00:06
#    ---------------------------- ----------- 2.9/4.0 MB 199.3 kB/s eta 0:00:06
#    ------------------------------- -------- 3.1/4.0 MB 190.4 kB/s eta 0:00:05
#    ------------------------------- -------- 3.1/4.0 MB 190.4 kB/s eta 0:00:05
#    ------------------------------- -------- 3.1/4.0 MB 190.4 kB/s eta 0:00:05
#    ------------------------------- -------- 3.1/4.0 MB 190.4 kB/s eta 0:00:05
#    ------------------------------- -------- 3.1/4.0 MB 190.4 kB/s eta 0:00:05
#    ------------------------------- -------- 3.1/4.0 MB 190.4 kB/s eta 0:00:05
#    ------------------------------- -------- 3.1/4.0 MB 190.4 kB/s eta 0:00:05
#    ------------------------------- -------- 3.1/4.0 MB 190.4 kB/s eta 0:00:05
#    ------------------------------- -------- 3.1/4.0 MB 190.4 kB/s eta 0:00:05
#    ------------------------------- -------- 3.1/4.0 MB 190.4 kB/s eta 0:00:05
#    ------------------------------- -------- 3.1/4.0 MB 190.4 kB/s eta 0:00:05
#    --------------------------------- ------ 3.4/4.0 MB 179.7 kB/s eta 0:00:04
#    --------------------------------- ------ 3.4/4.0 MB 179.7 kB/s eta 0:00:04
#    --------------------------------- ------ 3.4/4.0 MB 179.7 kB/s eta 0:00:04
#    --------------------------------- ------ 3.4/4.0 MB 179.7 kB/s eta 0:00:04
#    --------------------------------- ------ 3.4/4.0 MB 179.7 kB/s eta 0:00:04
#    ------------------------------------ --- 3.7/4.0 MB 183.5 kB/s eta 0:00:02
#    ------------------------------------ --- 3.7/4.0 MB 183.5 kB/s eta 0:00:02
#    ------------------------------------ --- 3.7/4.0 MB 183.5 kB/s eta 0:00:02
#    ------------------------------------ --- 3.7/4.0 MB 183.5 kB/s eta 0:00:02
#    ------------------------------------ --- 3.7/4.0 MB 183.5 kB/s eta 0:00:02
#    ------------------------------------ --- 3.7/4.0 MB 183.5 kB/s eta 0:00:02
#    ------------------------------------ --- 3.7/4.0 MB 183.5 kB/s eta 0:00:02
#    ------------------------------------ --- 3.7/4.0 MB 183.5 kB/s eta 0:00:02
#    ---------------------------------------  3.9/4.0 MB 180.2 kB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 180.9 kB/s  0:00:21
# Installing collected packages: lxml
# Successfully installed lxml-6.0.2

# %%
df=pd.read_html('example.html')

# %%
df[0]
# Out:
#       Name  Age  Grade
# 0    Alice   10      5
# 1      Bob   11      6
# 2  Charlie    9      4

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\madhav yadav\myenv\lib\site-packages (from bs4) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\madhav yadav\myenv\lib\site-packages (from beautifulsoup4->bs4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\madhav yadav\myenv\lib\site-packages (from beautifulsoup4->bs4) (4.14.1)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2
