# %% [markdown]
# ## Email Spam Classifier witht he TF-IDF

# %% [markdown]
# ### Process of the Project
# 1. Preprocessing & Cleaning
# 2. Train test split
# 3. BOW and TF-IDF(sentence---->Vector) {preventing Data Leakage}
# 4. Trained Our Model

# %%
import pandas as pd 
messages = pd.read_csv('SMSSpamCollection',sep='\t',names=['level','message'])

# %% [markdown]
# ### Text Cleaning and Preprocessing

# %%
 
import re 
import nltk 
nltk.download('stopwords')
from nltk.corpus import stopwords 
from nltk.stem.porter import PorterStemmer 
ps=PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Madhav
# [nltk_data]     Yadav\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus = []
for i in range(0,len(messages)):
    review=re.sub('[^a-zA-Z]',' ',messages['message'][i])  ## sub() stands for subtitution 
    review=review.lower()
    review=review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['go jurong point crazi avail bugi n great world la e buffet cine got amor wat',
#  'ok lar joke wif u oni',
#  'free entri wkli comp win fa cup final tkt st may text fa receiv entri question std txt rate c appli',
#  'u dun say earli hor u c alreadi say',
#  'nah think goe usf live around though',
#  'freemsg hey darl week word back like fun still tb ok xxx std chg send rcv',
#  'even brother like speak treat like aid patent',
#  'per request mell mell oru minnaminungint nurungu vettam set callertun caller press copi friend callertun',
#  'winner valu network custom select receivea prize reward claim call claim code kl valid hour',
#  'mobil month u r entitl updat latest colour mobil camera free call mobil updat co free',
#  'gonna home soon want talk stuff anymor tonight k cri enough today',
#  'six chanc win cash pound txt csh send cost p day day tsandc appli repli hl info',
#  'urgent week free membership prize jackpot txt word claim c www dbuk net lccltd pobox ldnw rw',
# ...

# %%
y=pd.get_dummies(messages['level'])
y=y.iloc[:,0].values
l=[]
for i in range(len(y)):
    if y[i]==True:
        l.append(1)
    else:
        l.append(0) 
y=l
x=corpus

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
# Out:
# ['cant pick phone right pl send messag',
#  'nice nice work',
#  'hey anyway',
#  'thank much skype wit kz sura didnt get pleasur compani hope good given ultimatum oh countin aburo enjoy',
#  'lunch onlin',
#  'mayb could get book tomo return immedi someth',
#  'play smash bro lt gt religi',
#  'thought king hill thing',
#  'reach ard min ok',
#  'tell think plu go stop run',
#  'pl speak custom machan',
#  'call cost guess isnt bad miss ya need ya want ya love ya',
#  'yeah go bed back midnight',
#  'tessi pl favor pl convey birthday wish nimya pl dnt forget today birthday shija',
#  'show wot say could u c dust',
#  'check realli miss see jeremiah great month',
#  'time want come',
#  'forget own privat properti good boy alway passion kiss',
#  'sorri call later',
#  'wife knew time murder exactli',
#  'dint tell anyth angri told abi',
#  'see half hour',
#  'run away frm u walk slowli amp kill u care enough stop',
#  'never believ actual got taunton wow',
# ...

# %% [markdown]
# ### BOW & TF-IDF to sentence ---> Vector

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 2500 , ngram_range=(1,2))

# %%
X_train = cv.fit_transform(x_train).toarray()
X_test = cv.transform(x_test).toarray()

# %% [markdown]
# ### Train Our Model

# %%
from sklearn.naive_bayes import MultinomialNB
model_tfidf = MultinomialNB().fit(X_train,y_train)

# %%
## Prediction 
y_pred=model_tfidf.predict(X_test)

# %%
## Accuracy 
from sklearn.metrics import accuracy_score , classification_report
score=accuracy_score(y_test,y_pred)
print(round(score,4)*100,"%")
# Out:
# 98.83 %

# %%
## Classification report
report=classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       139
#            1       0.99      0.99      0.99       976
#
#     accuracy                           0.98      1115
#    macro avg       0.95      0.96      0.96      1115
# weighted avg       0.98      0.98      0.98      1115

# %% [markdown]
# ## Using the Lemmatization Text Preprocessing

# %%
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Madhav
# [nltk_data]     Yadav\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
lemmatizer=WordNetLemmatizer()

# %%
corpus = []
for i in range(0,len(messages)):
    review=re.sub('[^a-zA-Z]',' ',messages['message'][i])  ## sub() stands for subtitution 
    review=review.lower()
    review=review.split()
    review = [lemmatizer.lemmatize(word,pos='v') for word in review ]
    review = ' '.join(review)
    corpus.append(review)

# %%
x=corpus 
y=
# Out:
# ['go until jurong point crazy available only in bugis n great world la e buffet cine there get amore wat',
#  'ok lar joke wif u oni',
#  'free entry in a wkly comp to win fa cup final tkts st may text fa to to receive entry question std txt rate t c s apply over s',
#  'u dun say so early hor u c already then say',
#  'nah i don t think he go to usf he live around here though',
#  'freemsg hey there darling it s be week s now and no word back i d like some fun you up for it still tb ok xxx std chgs to send to rcv',
#  'even my brother be not like to speak with me they treat me like aid patent',
#  'as per your request melle melle oru minnaminunginte nurungu vettam have be set as your callertune for all callers press to copy your friends callertune',
#  'winner as a value network customer you have be select to receivea prize reward to claim call claim code kl valid hours only',
# ...

# %%
y=pd.get_dummies(messages['level'])
y=y.iloc[:,0].values
l=[]
for i in range(len(y)):
    if y[i]==True:
        l.append(1)
    else:
        l.append(0) 
y=l
x=corpus

# %%
# split the data into train and test 
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 2500 , ngram_range=(1,2))

# %%
X_train = cv.fit_transform(x_train).toarray()
X_test = cv.transform(x_test).toarray()

# %%
from sklearn.naive_bayes import MultinomialNB
model_tfidf = MultinomialNB().fit(X_train,y_train)

# %%
y_pred=model_tfidf.predict(X_test)

# %%
## Accuracy 
from sklearn.metrics import accuracy_score , classification_report
score=accuracy_score(y_test,y_pred)
print(round(score,3)*100,"%")
# Out:
# 98.1 %

# %%
## Classification report
report1=classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       139
#            1       0.99      0.99      0.99       976
#
#     accuracy                           0.98      1115
#    macro avg       0.95      0.96      0.96      1115
# weighted avg       0.98      0.98      0.98      1115

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       139
#            1       0.99      0.99      0.99       976
#
#     accuracy                           0.98      1115
#    macro avg       0.95      0.96      0.96      1115
# weighted avg       0.98      0.98      0.98      1115
