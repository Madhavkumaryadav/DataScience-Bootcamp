# %%
word='''
APJ Abdul Kalam Speech on Education and Nation-Building
Dr. Kalam’s speeches on education emphasize the value of 
curiosity, critical thinking, and hard work. He believed that
every child can make a difference if given the right guidance.
The Apj Abdul Kalam Speech on education is often quoted to 
highlight the power of learning in shaping India’s future. 
Many of his ideas still guide students and teachers today.


He often said, “Education is the most powerful weapon
which you can use to change the world.” Schools, colleges,
and even parents cite his teachings to encourage learning and 
discipline. For more resources on speech for children, explore
Kids Topics and Learning Activities for inspiration.


Dr. APJ Abdul Kalam Full Name and Biography in English
APJ Abdul Kalam full name is Avul Pakir Jainulabdeen Abdul
Kalam. His life story is full of struggles, achievements, and
contributions to science and society. His childhood in
Rameswaram and early education shaped his values of simplicity 
and dedication. You can read more about his life in various 
formats, including the popular “APJ Abdul Kalam Biography in English PDF”.


His biography is often included in English essay
topics and moral education. For a detailed essay, you can refer
to Essay on APJ Abdul Kalam or explore comparisons with Essay on Swami Vivekananda.
'''

# %%
from nltk.stem import PorterStemmer
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Madhav
# [nltk_data]     Yadav\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Madhav
# [nltk_data]     Yadav\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords.words('arabic')
# Out:
# ['إذ',
#  'إذا',
#  'إذما',
#  'إذن',
#  'أف',
#  'أقل',
#  'أكثر',
#  'ألا',
#  'إلا',
#  'التي',
#  'الذي',
#  'الذين',
#  'اللاتي',
#  'اللائي',
#  'اللتان',
#  'اللتيا',
#  'اللتين',
#  'اللذان',
#  'اللذين',
#  'اللواتي',
#  'إلى',
#  'إليك',
#  'إليكم',
#  'إليكما',
#  'إليكن',
#  'أم',
#  'أما',
#  'أما',
#  'إما',
#  'أن',
#  'إن',
#  'إنا',
#  'أنا',
#  'أنت',
#  'أنتم',
#  'أنتما',
#  'أنتن',
#  'إنما',
#  'إنه',
#  'أنى',
#  'أنى',
#  'آه',
#  'آها',
#  'أو',
#  'أولاء',
#  'أولئك',
#  'أوه',
#  'آي',
#  'أي',
#  'أيها',
#  'إي',
#  'أين',
#  'أين',
#  'أينما',
#  'إيه',
#  'بخ',
#  'بس',
#  'بعد',
#  'بعض',
#  'بك',
#  'بكم',
#  'بكم',
#  'بكما',
#  'بكن',
#  'بل',
#  'بلى',
#  'بما',
#  'بماذا',
#  'بمن',
#  'بنا',
#  'به',
#  'بها',
#  'بهم',
#  'بهما',
#  'بهن',
#  'بي',
#  'بين',
#  'بيد',
#  'تلك',
#  'تلكم',
#  'تلكما',
#  'ته',
#  'تي',
#  'تين',
#  'تينك',
#  'ثم',
#  'ثمة',
#  'حاشا',
#  'حبذا',
#  'حتى',
#  'حيث',
#  'حيثما',
#  'حين',
#  'خلا',
#  'دون',
# ...

# %%
from nltk.stem import PorterStemmer
stemmer=PorterStemmer()

# %%
## Paragraph into divide the sentences 
sentences=nltk.sent_tokenize(word)  ## nltk.sent_tokenize() --> It's the paragraph to sentence tokenizer

# %%
type(sentences)
# Out:
# list

# %%
from nltk.stem import SnowballStemmer
snowballstemmer=SnowballStemmer('english')

# %%
## Available Language inside the snowballstemmer classes or supported language 

print(' '.join(SnowballStemmer.languages))
# Out:
# arabic danish dutch english finnish french german hungarian italian norwegian porter portuguese romanian russian spanish swedish

# %%
## Apply Stopwords and Filter And then Apply Stemming 
# snowballstemmer.stem()
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

for i in range(len(sentences)):
    # words=nltk.word_tokenize(sentences[i])
    words=[lemmatizer.lemmatize(word.lower(),pos='v') for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = ' '.join(words) ## Converting all the list of words into sentences

# %%
sentences
# Out:
# ['apj abdul kalam speech education nation-building dr. kalam ’ speeches education emphasize value curiosity , critical think , hard work .',
#  'he believe every child make difference give right guidance .',
#  'the apj abdul kalam speech education often quote highlight power learn shape india ’ future .',
#  'many ideas still guide students teachers today .',
#  'he often say , “ education powerful weapon use change world. ” school , colleges , even parent cite teachings encourage learn discipline .',
#  'for resources speech children , explore kid topics learn activities inspiration .',
#  'dr. apj abdul kalam full name biography english apj abdul kalam full name avul pakir jainulabdeen abdul kalam .',
#  'his life story full struggle , achievements , contributions science society .',
#  'his childhood rameswaram early education shape value simplicity dedication .',
#  'you read life various format , include popular “ apj abdul kalam biography english pdf ” .',
# ...

# %%
snowballstemmer.stem('history')
# Out:
# 'histori'

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
lemmatizer.lemmatize('history','v')
# Out:
# 'history'
