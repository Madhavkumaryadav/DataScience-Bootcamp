# %% [markdown]
# ### Steps
# - Preprocessing and Cleaning
# - Train test split
# - BOW,TF-IDF,WOrd2vec
# - Train ML Algorithms

# %%
import pandas as pd

# %%
df=pd.read_csv('amazon_product_reviews.csv',encoding='latin')

# %%
df.head()
# Out:
#    Review ID                                         text  \
# 0          1                 Just OK but won't repurchase
# 1          2                                   Good scent
# 2          3  Overpowering, do not buy if you have pets!!
# 3          4             Surprisingly lovely and fragrant
# 4          5                            Doesn't like heat
#
#                                                 Body  sentiment  Product id
# 0  I prefer candles to fragrance my home but want...          3  B09VTNCFKL
# 1  Love this reed diffuser! This is a good altern...          5  B09VTNCFKL
# 2  Update: the seller kindly refunded me, and tha...          1  B09VTNCFKL
# 3  I bought based only on reviews - wanted someth...          5  B0CC3SZ5F4
# 4  I'll start by saying the product is great. Sme...          5  B09VTNCFKL

# %%
x=df['Body']
y=df['sentiment']

# %%
d={
    'review':x,
    'rating':y
}
data=pd.DataFrame(d)

# %%
data.head()
# Out:
#                                               review  rating
# 0  I prefer candles to fragrance my home but want...       3
# 1  Love this reed diffuser! This is a good altern...       5
# 2  Update: the seller kindly refunded me, and tha...       1
# 3  I bought based only on reviews - wanted someth...       5
# 4  I'll start by saying the product is great. Sme...       5

# %%
data.shape
# Out:
# (1960, 2)

# %%
## Missing values 
data.isnull().sum()
# Out:
# review    0
# rating    0
# dtype: int64

# %%
data['rating'].unique()
# Out:
# array([3, 5, 1, 4, 2], dtype=int64)

# %%
a,b,c,d,e=data['rating'].value_counts()

# %%
p=[a,b,c,d,e]
q=[i for i in range(1,6)]
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.pairplot(data,height=5,markers='o',hue=['r','b',')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sns.pairplot(data,height=5,markers='o',hue=data['rating'].unique())
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:2119, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2117 # Set up the PairGrid
#    2118 grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2119 grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2120                 hue_order=hue_order, palette=palette, corner=corner,
#    2121                 height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2123 # Add the markers here as PairGrid has figured out how many levels of the
# ...
