# %%
## First you have to install the pandas library 
## you run the inside jupyter notebook : !pip install pandas 
## Command prompt : pip innstall pandas 

# then import the pandas library in the 
import pandas as pd

# %%
## Load the data set in the csv format 
## make sure your file must be csv format 
data=pd.read_csv('aids.csv')

# %%
data.head()
# Out:
#        Country  Year  Data.AIDS-Related Deaths.AIDS Orphans  \
# 0  Afghanistan  1990                                    100
# 1      Algeria  1990                                    200
# 2       Angola  1990                                   1300
# 3    Argentina  1990                                    500
# 4      Armenia  1990                                    100
#
#    Data.AIDS-Related Deaths.Adults  Data.AIDS-Related Deaths.All Ages  \
# 0                              100                                100
# 1                              100                                100
# 2                              500                               1000
# 3                              200                                500
# 4                              100                                100
#
#    Data.AIDS-Related Deaths.Children  Data.AIDS-Related Deaths.Female Adults  \
# 0                                100                                     100
# 1                                100                                     100
# 2                                500                                     200
# 3                                100                                     100
# 4                                100                                     100
#
#    Data.AIDS-Related Deaths.Male Adults  Data.HIV Prevalence.Adults  \
# 0                                   100                         0.1
# 1                                   100                         0.1
# 2                                   200                         0.2
# 3                                   200                         0.1
# 4                                   100                         0.1
#
#    Data.HIV Prevalence.Young Men  ...  Data.New HIV Infections.Female Adults  \
# 0                            0.1  ...                                    100
# 1                            0.1  ...                                    100
# 2                            0.1  ...                                   1700
# 3                            0.1  ...                                   1200
# 4                            0.1  ...                                    100
#
#    Data.New HIV Infections.Children  Data.New HIV Infections.All Ages  \
# 0                               100                               100
# 1                               100                               100
# 2                              1000                              3400
# 3                               200                              4500
# 4                               100                               100
#
#    Data.New HIV Infections.Adults  \
# 0                             100
# 1                             100
# 2                            2800
# 3                            4400
# 4                             100
#
#    Data.New HIV Infections.Incidence Rate Among Adults  \
# 0                                               0.01
# 1                                               0.01
# 2                                               0.47
# 3                                               0.19
# 4                                               0.01
#
#    Data.People Living with HIV.Total  Data.People Living with HIV.Male Adults  \
# 0                                500                                      500
# 1                                500                                      500
# 2                              12000                                     4600
# 3                              13000                                     9100
# 4                                100                                      100
#
#    Data.People Living with HIV.Female Adults  \
# 0                                        100
# 1                                        200
# 2                                       6100
# 3                                       3700
# 4                                        100
#
#    Data.People Living with HIV.Children  Data.People Living with HIV.Adults
# 0                                   100                                 500
# 1                                   100                                 500
# 2                                  1100                               11000
# 3                                   200                               13000
# 4                                   100                                 100
#
# [5 rows x 23 columns]

# %%
data.head(2)
# Out:
#        Country  Year  Data.AIDS-Related Deaths.AIDS Orphans  \
# 0  Afghanistan  1990                                    100
# 1      Algeria  1990                                    200
#
#    Data.AIDS-Related Deaths.Adults  Data.AIDS-Related Deaths.All Ages  \
# 0                              100                                100
# 1                              100                                100
#
#    Data.AIDS-Related Deaths.Children  Data.AIDS-Related Deaths.Female Adults  \
# 0                                100                                     100
# 1                                100                                     100
#
#    Data.AIDS-Related Deaths.Male Adults  Data.HIV Prevalence.Adults  \
# 0                                   100                         0.1
# 1                                   100                         0.1
#
#    Data.HIV Prevalence.Young Men  ...  Data.New HIV Infections.Female Adults  \
# 0                            0.1  ...                                    100
# 1                            0.1  ...                                    100
#
#    Data.New HIV Infections.Children  Data.New HIV Infections.All Ages  \
# 0                               100                               100
# 1                               100                               100
#
#    Data.New HIV Infections.Adults  \
# 0                             100
# 1                             100
#
#    Data.New HIV Infections.Incidence Rate Among Adults  \
# 0                                               0.01
# 1                                               0.01
#
#    Data.People Living with HIV.Total  Data.People Living with HIV.Male Adults  \
# 0                                500                                      500
# 1                                500                                      500
#
#    Data.People Living with HIV.Female Adults  \
# 0                                        100
# 1                                        200
#
#    Data.People Living with HIV.Children  Data.People Living with HIV.Adults
# 0                                   100                                 500
# 1                                   100                                 500
#
# [2 rows x 23 columns]

# %%
df1=data.tail()

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.to_csv('test.csv')

# %%
ls
# Out:
#  Volume in drive C is Local Disk
#  Volume Serial Number is 845B-B5FF
#
#  Directory of C:\Users\Madhav Yadav\OneDrive\Desktop\desktop1\Datascience_bootcamp\pandas
#
# 15-02-2026  09:30    <DIR>          .
# 19-02-2026  10:54    <DIR>          ..
# 15-02-2026  08:32    <DIR>          .ipynb_checkpoints
# 15-02-2026  07:28           457,895 aids.csv
# 15-02-2026  08:39            16,356 call_center.xlsx
# 15-02-2026  08:44            21,240 hist.xlsx
# 15-02-2026  09:30            89,518 Pandas_day_1.ipynb
# 15-02-2026  08:28               678 result.csv
# 15-02-2026  08:29               678 result2.csv
# 15-02-2026  08:33               131 result3.csv
# 19-02-2026  11:01             1,444 test.csv
#                8 File(s)        587,940 bytes
#                3 Dir(s)  38,154,575,872 bytes free

# %%
t= pd.read_csv('test.csv',header=None,names=['a','b','c','d','e','f','g','h'],skiprows=[0,3])

# %%
t
# Out:
#                                                                                                                          a  \
# 2754 Venezuela (Bolivarian Republic of) 2020 39000  3900  4200  500  2500  1400 0.5  0.1 0.2 1800  1000  1000  500    2200
# 2755 Viet Nam                           2020 83000  3700  3800  100  1000  2900 0.3  0.1 0.1 5300  3900  2000  500    6100
# 2757 Zambia                             2020 700000 19000 24000 5300 10000 8700 11.1 2.3 6.0 58000 21000 39000 8300  69000
# 2758 Zimbabwe                           2020 540000 19000 22000 3500 9500  9300 11.9 2.9 5.2 19000 7300  13000 5100  25000
#
#                                                                                                                          b  \
# 2754 Venezuela (Bolivarian Republic of) 2020 39000  3900  4200  500  2500  1400 0.5  0.1 0.2 1800  1000  1000  500    1900
# 2755 Viet Nam                           2020 83000  3700  3800  100  1000  2900 0.3  0.1 0.1 5300  3900  2000  500    5900
# 2757 Zambia                             2020 700000 19000 24000 5300 10000 8700 11.1 2.3 6.0 58000 21000 39000 8300  61000
# 2758 Zimbabwe                           2020 540000 19000 22000 3500 9500  9300 11.9 2.9 5.2 19000 7300  13000 5100  20000
#
#                                                                                                                         c  \
# 2754 Venezuela (Bolivarian Republic of) 2020 39000  3900  4200  500  2500  1400 0.5  0.1 0.2 1800  1000  1000  500   0.09
# 2755 Viet Nam                           2020 83000  3700  3800  100  1000  2900 0.3  0.1 0.1 5300  3900  2000  500   0.08
# 2757 Zambia                             2020 700000 19000 24000 5300 10000 8700 11.1 2.3 6.0 58000 21000 39000 8300  6.07
# 2758 Zimbabwe                           2020 540000 19000 22000 3500 9500  9300 11.9 2.9 5.2 19000 7300  13000 5100  2.44
#
#                                                                                                                            d  \
# 2754 Venezuela (Bolivarian Republic of) 2020 39000  3900  4200  500  2500  1400 0.5  0.1 0.2 1800  1000  1000  500    100000
# 2755 Viet Nam                           2020 83000  3700  3800  100  1000  2900 0.3  0.1 0.1 5300  3900  2000  500    250000
# 2757 Zambia                             2020 700000 19000 24000 5300 10000 8700 11.1 2.3 6.0 58000 21000 39000 8300  1500000
# 2758 Zimbabwe                           2020 540000 19000 22000 3500 9500  9300 11.9 2.9 5.2 19000 7300  13000 5100  1300000
#
#                                                                                                                           e  \
# 2754 Venezuela (Bolivarian Republic of) 2020 39000  3900  4200  500  2500  1400 0.5  0.1 0.2 1800  1000  1000  500    60000
# 2755 Viet Nam                           2020 83000  3700  3800  100  1000  2900 0.3  0.1 0.1 5300  3900  2000  500   160000
# 2757 Zambia                             2020 700000 19000 24000 5300 10000 8700 11.1 2.3 6.0 58000 21000 39000 8300  520000
# 2758 Zimbabwe                           2020 540000 19000 22000 3500 9500  9300 11.9 2.9 5.2 19000 7300  13000 5100  470000
#
#                                                                                                                           f  \
# 2754 Venezuela (Bolivarian Republic of) 2020 39000  3900  4200  500  2500  1400 0.5  0.1 0.2 1800  1000  1000  500    40000
# 2755 Viet Nam                           2020 83000  3700  3800  100  1000  2900 0.3  0.1 0.1 5300  3900  2000  500    80000
# 2757 Zambia                             2020 700000 19000 24000 5300 10000 8700 11.1 2.3 6.0 58000 21000 39000 8300  850000
# 2758 Zimbabwe                           2020 540000 19000 22000 3500 9500  9300 11.9 2.9 5.2 19000 7300  13000 5100  720000
#
#                                                                                                                          g  \
# 2754 Venezuela (Bolivarian Republic of) 2020 39000  3900  4200  500  2500  1400 0.5  0.1 0.2 1800  1000  1000  500    3300
# 2755 Viet Nam                           2020 83000  3700  3800  100  1000  2900 0.3  0.1 0.1 5300  3900  2000  500    4300
# 2757 Zambia                             2020 700000 19000 24000 5300 10000 8700 11.1 2.3 6.0 58000 21000 39000 8300  82000
# 2758 Zimbabwe                           2020 540000 19000 22000 3500 9500  9300 11.9 2.9 5.2 19000 7300  13000 5100  79000
#
#                                                                                                                            h
# 2754 Venezuela (Bolivarian Republic of) 2020 39000  3900  4200  500  2500  1400 0.5  0.1 0.2 1800  1000  1000  500     99000
# 2755 Viet Nam                           2020 83000  3700  3800  100  1000  2900 0.3  0.1 0.1 5300  3900  2000  500    240000
# 2757 Zambia                             2020 700000 19000 24000 5300 10000 8700 11.1 2.3 6.0 58000 21000 39000 8300  1400000
# 2758 Zimbabwe                           2020 540000 19000 22000 3500 9500  9300 11.9 2.9 5.2 19000 7300  13000 5100  1200000

# %%
# d=pd.read_csv('test.csv'na_values=1)

# %%
d=pd.read_excel('hist.xlsx')

# %%
d.describe()
# Out:
#        Unnamed: 0                        Unnamed: 1  Unnamed: 2  Unnamed: 3
# count          84                                85     84.0000     84.0000
# unique         84                                85     80.0000     83.0000
# top          Year  Annual Returns on Investments in      0.0038      0.0466
# freq            1                                 1      5.0000      2.0000

# %%
d.head()
# Out:
#   Unnamed: 0                        Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0        NaN                               NaN        NaN        NaN
# 1        NaN                               NaN        NaN        NaN
# 2        NaN                               NaN        NaN        NaN
# 3        NaN                               NaN        NaN        NaN
# 4        NaN  Annual Returns on Investments in        NaN        NaN

# %%
d.to_csv('result2.csv',index=False,header=False,sep="#",)

# %%
d.to_csv('result3.csv',index=False,header=True,columns=['Unnamed: 0','Unnamed: 1','Unnamed: 2','Unnamed: 3'])

# %%
type(d['Unnamed: 1'])
# Out:
# pandas.core.series.Series

# %%
d[['Unnamed: 0','Unnamed: 1']].dtypes
# Out:
# Unnamed: 0    object
# Unnamed: 1    object
# dtype: object

# %%
import pandas as pd

# %%
aids=pd.read_csv('aids.csv')

# %%
aids.head()
# Out:
#        Country  Year  Data.AIDS-Related Deaths.AIDS Orphans  \
# 0  Afghanistan  1990                                    100
# 1      Algeria  1990                                    200
# 2       Angola  1990                                   1300
# 3    Argentina  1990                                    500
# 4      Armenia  1990                                    100
#
#    Data.AIDS-Related Deaths.Adults  Data.AIDS-Related Deaths.All Ages  \
# 0                              100                                100
# 1                              100                                100
# 2                              500                               1000
# 3                              200                                500
# 4                              100                                100
#
#    Data.AIDS-Related Deaths.Children  Data.AIDS-Related Deaths.Female Adults  \
# 0                                100                                     100
# 1                                100                                     100
# 2                                500                                     200
# 3                                100                                     100
# 4                                100                                     100
#
#    Data.AIDS-Related Deaths.Male Adults  Data.HIV Prevalence.Adults  \
# 0                                   100                         0.1
# 1                                   100                         0.1
# 2                                   200                         0.2
# 3                                   200                         0.1
# 4                                   100                         0.1
#
#    Data.HIV Prevalence.Young Men  ...  Data.New HIV Infections.Female Adults  \
# 0                            0.1  ...                                    100
# 1                            0.1  ...                                    100
# 2                            0.1  ...                                   1700
# 3                            0.1  ...                                   1200
# 4                            0.1  ...                                    100
#
#    Data.New HIV Infections.Children  Data.New HIV Infections.All Ages  \
# 0                               100                               100
# 1                               100                               100
# 2                              1000                              3400
# 3                               200                              4500
# 4                               100                               100
#
#    Data.New HIV Infections.Adults  \
# 0                             100
# 1                             100
# 2                            2800
# 3                            4400
# 4                             100
#
#    Data.New HIV Infections.Incidence Rate Among Adults  \
# 0                                               0.01
# 1                                               0.01
# 2                                               0.47
# 3                                               0.19
# 4                                               0.01
#
#    Data.People Living with HIV.Total  Data.People Living with HIV.Male Adults  \
# 0                                500                                      500
# 1                                500                                      500
# 2                              12000                                     4600
# 3                              13000                                     9100
# 4                                100                                      100
#
#    Data.People Living with HIV.Female Adults  \
# 0                                        100
# 1                                        200
# 2                                       6100
# 3                                       3700
# 4                                        100
#
#    Data.People Living with HIV.Children  Data.People Living with HIV.Adults
# 0                                   100                                 500
# 1                                   100                                 500
# 2                                  1100                               11000
# 3                                   200                               13000
# 4                                   100                                 100
#
# [5 rows x 23 columns]

# %%
# We have to able to save the thiese file for the different file extenxion 
aids.to_html('aids.html')

# %%
## Read the html file 
read_html= pd.read_html('aids.html')

# %%
from_file = pd.read_csv('aids.csv')

# %%
from_file.to_pickle('my_pickle')

# %%
pwd()
# Out:
# 'C:\\Users\\Madhav Yadav\\OneDrive\\Desktop\\desktop1\\Datascience_bootcamp\\pandas'

# %%
from_file
# Out:
#                                  Country  Year  \
# 0                            Afghanistan  1990
# 1                                Algeria  1990
# 2                                 Angola  1990
# 3                              Argentina  1990
# 4                                Armenia  1990
# ...                                  ...   ...
# 2754  Venezuela (Bolivarian Republic of)  2020
# 2755                            Viet Nam  2020
# 2756                               Yemen  2020
# 2757                              Zambia  2020
# 2758                            Zimbabwe  2020
#
#       Data.AIDS-Related Deaths.AIDS Orphans  Data.AIDS-Related Deaths.Adults  \
# 0                                       100                              100
# 1                                       200                              100
# 2                                      1300                              500
# 3                                       500                              200
# 4                                       100                              100
# ...                                     ...                              ...
# 2754                                  39000                             3900
# 2755                                  83000                             3700
# 2756                                   5500                              500
# 2757                                 700000                            19000
# 2758                                 540000                            19000
#
#       Data.AIDS-Related Deaths.All Ages  Data.AIDS-Related Deaths.Children  \
# 0                                   100                                100
# 1                                   100                                100
# 2                                  1000                                500
# 3                                   500                                100
# 4                                   100                                100
# ...                                 ...                                ...
# 2754                               4200                                500
# 2755                               3800                                100
# 2756                                500                                100
# 2757                              24000                               5300
# 2758                              22000                               3500
#
#       Data.AIDS-Related Deaths.Female Adults  \
# 0                                        100
# 1                                        100
# 2                                        200
# 3                                        100
# 4                                        100
# ...                                      ...
# 2754                                    2500
# 2755                                    1000
# 2756                                     100
# 2757                                   10000
# 2758                                    9500
#
#       Data.AIDS-Related Deaths.Male Adults  Data.HIV Prevalence.Adults  \
# 0                                      100                         0.1
# 1                                      100                         0.1
# 2                                      200                         0.2
# 3                                      200                         0.1
# 4                                      100                         0.1
# ...                                    ...                         ...
# 2754                                  1400                         0.5
# 2755                                  2900                         0.3
# 2756                                   200                         0.1
# 2757                                  8700                        11.1
# 2758                                  9300                        11.9
#
#       Data.HIV Prevalence.Young Men  ...  \
# 0                               0.1  ...
# 1                               0.1  ...
# 2                               0.1  ...
# 3                               0.1  ...
# 4                               0.1  ...
# ...                             ...  ...
# 2754                            0.1  ...
# 2755                            0.1  ...
# 2756                            0.1  ...
# 2757                            2.3  ...
# 2758                            2.9  ...
#
#       Data.New HIV Infections.Female Adults  Data.New HIV Infections.Children  \
# 0                                       100                               100
# 1                                       100                               100
# 2                                      1700                              1000
# 3                                      1200                               200
# 4                                       100                               100
# ...                                     ...                               ...
# 2754                                   1000                               500
# 2755                                   2000                               500
# 2756                                    500                               100
# 2757                                  39000                              8300
# 2758                                  13000                              5100
#
#       Data.New HIV Infections.All Ages  Data.New HIV Infections.Adults  \
# 0                                  100                             100
# 1                                  100                             100
# 2                                 3400                            2800
# 3                                 4500                            4400
# 4                                  100                             100
# ...                                ...                             ...
# 2754                              2200                            1900
# 2755                              6100                            5900
# 2756                              1100                            1000
# 2757                             69000                           61000
# 2758                             25000                           20000
#
#       Data.New HIV Infections.Incidence Rate Among Adults  \
# 0                                                  0.01
# 1                                                  0.01
# 2                                                  0.47
# 3                                                  0.19
# 4                                                  0.01
# ...                                                 ...
# 2754                                               0.09
# 2755                                               0.08
# 2756                                               0.05
# 2757                                               6.07
# 2758                                               2.44
#
#       Data.People Living with HIV.Total  \
# 0                                   500
# 1                                   500
# 2                                 12000
# 3                                 13000
# 4                                   100
# ...                                 ...
# 2754                             100000
# 2755                             250000
# 2756                              11000
# 2757                            1500000
# 2758                            1300000
#
#       Data.People Living with HIV.Male Adults  \
# 0                                         500
# 1                                         500
# 2                                        4600
# 3                                        9100
# 4                                         100
# ...                                       ...
# 2754                                    60000
# 2755                                   160000
# 2756                                     6300
# 2757                                   520000
# 2758                                   470000
#
#       Data.People Living with HIV.Female Adults  \
# 0                                           100
# 1                                           200
# 2                                          6100
# 3                                          3700
# 4                                           100
# ...                                         ...
# 2754                                      40000
# 2755                                      80000
# 2756                                       3700
# 2757                                     850000
# 2758                                     720000
#
#       Data.People Living with HIV.Children  Data.People Living with HIV.Adults
# 0                                      100                                 500
# 1                                      100                                 500
# 2                                     1100                               11000
# 3                                      200                               13000
# 4                                      100                                 100
# ...                                    ...                                 ...
# 2754                                  3300                               99000
# 2755                                  4300                              240000
# 2756                                  1000                               10000
# 2757                                 82000                             1400000
# 2758                                 79000                             1200000
#
# [2759 rows x 23 columns]

# %%
df1 = pd.DataFrame([[1, 2], [3, 4]], columns=["A", "B"])
df2 = pd.DataFrame([[5, 6], [7, 8]], columns=["C", "D"])

# %%
store = pd.HDFStore("store.h5", "w")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'tables'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 store = pd.HDFStore("store.h5", "w")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\pytables.py:579, in HDFStore.__init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     576 if "format" in kwargs:
#     577     raise ValueError("format is not a defined argument for HDFStore")
# --> 579 tables = import_optional_dependency("tables")
#     581 if complib is not None and complib not in tables.filters.all_complibs:
#     582     raise ValueError(
#     583         f"complib only supports {tables.filters.all_complibs} compression."
#     584     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'pytables'.  Use pip or conda to install pytables.

# %%
# !pip install pytable
# Out:
# Collecting pytable
#   Downloading pytable-0.8.23a.zip (264 kB)
#   Downloading pytable-0.8.22a.zip (264 kB)
#   Downloading pytable-0.8.21a.tar.gz (200 kB)
#
# The conflict is caused by:
#     pytable 0.8.23a0 depends on basicproperty>=0.6.9a
#     pytable 0.8.22a0 depends on basicproperty>=0.6.9a
#     pytable 0.8.21a0 depends on basicproperty>=0.6.9a
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip attempt to solve the dependency conflict
# ERROR: Cannot install pytable==0.8.21a0, pytable==0.8.22a0 and pytable==0.8.23a0 because these package versions have conflicting dependencies.
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/user_guide/#fixing-conflicting-dependencies
# WARNING: You are using pip version 21.2.3; however, version 26.0.1 is available.
# You should consider upgrading via the 'C:\Users\Madhav Yadav\OneDrive\Desktop\desktop1\Datascience_bootcamp\nlp\nlpvenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\madhav yadav\onedrive\desktop\desktop1\datascience_bootcamp\nlp\nlpvenv\lib\site-packages (21.2.3)
# Collecting pip
#   Using cached pip-26.0.1-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.3
#     Uninstalling pip-21.2.3:
#       Successfully uninstalled pip-21.2.3
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Madhav Yadav\\AppData\\Local\\Temp\\pip-uninstall-3up1_0r_\\pip.exe'
# Check the permissions.

# %%
pwd()
# Out:
# 'C:\\Users\\Madhav Yadav\\OneDrive\\Desktop\\desktop1\\Datascience_bootcamp\\pandas'
