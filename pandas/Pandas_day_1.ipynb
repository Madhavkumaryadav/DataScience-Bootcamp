# %%
## First you have to install the pandas library 
## you run the inside jupyter notebook : !pip install pandas 
## Command prompt : pip innstall pandas 

# then import the pandas library in the 
import pandas as pd

# %%
## Load the data set in the csv format 
## make sure your file must be csv format 
data=pd.read_csv('aids.csv')

# %%
data.head()
# Out:
#        Country  Year  Data.AIDS-Related Deaths.AIDS Orphans  \
# 0  Afghanistan  1990                                    100
# 1      Algeria  1990                                    200
# 2       Angola  1990                                   1300
# 3    Argentina  1990                                    500
# 4      Armenia  1990                                    100
#
#    Data.AIDS-Related Deaths.Adults  Data.AIDS-Related Deaths.All Ages  \
# 0                              100                                100
# 1                              100                                100
# 2                              500                               1000
# 3                              200                                500
# 4                              100                                100
#
#    Data.AIDS-Related Deaths.Children  Data.AIDS-Related Deaths.Female Adults  \
# 0                                100                                     100
# ...

# %%
data.head(2)
# Out:
#        Country  Year  Data.AIDS-Related Deaths.AIDS Orphans  \
# 0  Afghanistan  1990                                    100
# 1      Algeria  1990                                    200
#
#    Data.AIDS-Related Deaths.Adults  Data.AIDS-Related Deaths.All Ages  \
# 0                              100                                100
# 1                              100                                100
#
#    Data.AIDS-Related Deaths.Children  Data.AIDS-Related Deaths.Female Adults  \
# 0                                100                                     100
# 1                                100                                     100
#
#    Data.AIDS-Related Deaths.Male Adults  Data.HIV Prevalence.Adults  \
# 0                                   100                         0.1
# 1                                   100                         0.1
#
#    Data.HIV Prevalence.Young Men  ...  Data.New HIV Infections.Female Adults  \
# ...

# %%
df1=data.tail()

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.to_csv('test.csv')

# %%
ls
# Out:
#  Volume in drive C is Local Disk
#  Volume Serial Number is 845B-B5FF
#
#  Directory of C:\Users\Madhav Yadav\OneDrive\Desktop\desktop1\Datascience_bootcamp\pandas
#
# 15-02-2026  07:41    <DIR>          .
# 15-02-2026  07:20    <DIR>          ..
# 15-02-2026  07:20    <DIR>          .ipynb_checkpoints
# 15-02-2026  07:28           457,895 aids.csv
# 15-02-2026  07:40            20,058 Pandas_day_1.ipynb
# 15-02-2026  07:41             1,444 test.csv
#                3 File(s)        479,397 bytes
#                3 Dir(s)  41,016,020,992 bytes free

# %%
t= pd.read_csv('test.csv',header=None,names=['a','b','c','d','e','f','g','h'],skiprows=[0,3])

# %%
t
# Out:
#                                                                                                                          a  \
# 2754 Venezuela (Bolivarian Republic of) 2020 39000  3900  4200  500  2500  1400 0.5  0.1 0.2 1800  1000  1000  500    2200
# 2755 Viet Nam                           2020 83000  3700  3800  100  1000  2900 0.3  0.1 0.1 5300  3900  2000  500    6100
# 2757 Zambia                             2020 700000 19000 24000 5300 10000 8700 11.1 2.3 6.0 58000 21000 39000 8300  69000
# 2758 Zimbabwe                           2020 540000 19000 22000 3500 9500  9300 11.9 2.9 5.2 19000 7300  13000 5100  25000
#
#                                                                                                                          b  \
# 2754 Venezuela (Bolivarian Republic of) 2020 39000  3900  4200  500  2500  1400 0.5  0.1 0.2 1800  1000  1000  500    1900
# ...

# %%
d=pd.read_csv('test.csv'na_values=1)

# %%
d
# Out:
#    Unnamed: 0                             Country  Year  \
# 0        2754  Venezuela (Bolivarian Republic of)  2020
# 1        2755                            Viet Nam  2020
# 2        2756                               Yemen  2020
# 3        2757                              Zambia  2020
# 4        2758                            Zimbabwe  2020
#
#    Data.AIDS-Related Deaths.AIDS Orphans  Data.AIDS-Related Deaths.Adults  \
# 0                                  39000                             3900
# 1                                  83000                             3700
# 2                                   5500                              500
# 3                                 700000                            19000
# 4                                 540000                            19000
#
#    Data.AIDS-Related Deaths.All Ages  Data.AIDS-Related Deaths.Children  \
# 0                               4200                                500
# ...

# %%
d.describe()
# Out:
#         Unnamed: 0    Year  Data.AIDS-Related Deaths.AIDS Orphans  \
# count     5.000000     5.0                               5.000000
# mean   2756.000000  2020.0                          273500.000000
# std       1.581139     0.0                          322501.550384
# min    2754.000000  2020.0                            5500.000000
# 25%    2755.000000  2020.0                           39000.000000
# 50%    2756.000000  2020.0                           83000.000000
# 75%    2757.000000  2020.0                          540000.000000
# max    2758.000000  2020.0                          700000.000000
#
#        Data.AIDS-Related Deaths.Adults  Data.AIDS-Related Deaths.All Ages  \
# count                          5.00000                           5.000000
# mean                        9220.00000                       10900.000000
# std                         9029.23031                       11161.093136
# min                          500.00000                         500.000000
# ...

# %%
d.dtypes
# Out:
# Unnamed: 0                                               int64
# Country                                                 object
# Year                                                     int64
# Data.AIDS-Related Deaths.AIDS Orphans                    int64
# Data.AIDS-Related Deaths.Adults                          int64
# Data.AIDS-Related Deaths.All Ages                        int64
# Data.AIDS-Related Deaths.Children                        int64
# Data.AIDS-Related Deaths.Female Adults                   int64
# Data.AIDS-Related Deaths.Male Adults                     int64
# Data.HIV Prevalence.Adults                             float64
# Data.HIV Prevalence.Young Men                          float64
# Data.HIV Prevalence.Young Women                        float64
# Data.New HIV Infections.Young Adults                     int64
# Data.New HIV Infections.Male Adults                      int64
# Data.New HIV Infections.Female Adults                    int64
# ...

# %%
d.to_csv('result2.csv',index=False,header=False,sep="#",)

# %%
d.to_csv('result3.csv',index=False,header=True,columns=['Data.AIDS-Related Deaths.AIDS Orphans',
                                                         'Data.AIDS-Related Deaths.Children'])

# %%
type(d['Data.AIDS-Related Deaths.Children'])
# Out:
# pandas.core.series.Series

# %%
type(d[['Data.AIDS-Related Deaths.Children']])
# Out:
# pandas.core.frame.DataFrame

# %%
d[['Data.AIDS-Related Deaths.Children','Data.AIDS-Related Deaths.AIDS Orphans']]
# Out:
#    Data.AIDS-Related Deaths.Children  Data.AIDS-Related Deaths.AIDS Orphans
# 0                                500                                  39000
# 1                                100                                  83000
# 2                                100                                   5500
# 3                               5300                                 700000
# 4                               3500                                 540000

# %%
d5=pd.read_excel('hist.xlsx')

# %%
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 df4=pd.read_html('https://www.basketball-reference.com/teams/DET/2026.html#all_per_game_stats')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)
#    1237         stacklevel=find_stack_level(),
#    1238     )
# ...

# %%
# Out:
# ...
#   Using cached lxml-6.0.2-cp310-cp310-win_amd64.whl.metadata (3.7 kB)
# Using cached lxml-6.0.2-cp310-cp310-win_amd64.whl (4.0 MB)
# ...
